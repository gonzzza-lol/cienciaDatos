# %% [markdown]
# # Tarea 1: el retrato de tu comuna
#
# **INF-396 Introducción a la Ciencia de Datos** · Universidad Técnica Federico Santa María
#
# | | |
# |---|---|
# | **Integrante 1** | *(nombre y rol)* |
# | **Integrante 2** | *(nombre y rol)* |
# | **Comuna** | *(complete)* |
# | **Comuna de contraste** | *(la que eligieron en el ítem 6)* |
#
# **Antes de empezar**
#
# 1. Copien este archivo a la raíz del repositorio y renómbrenlo como
#    `tarea1_apellido1_apellido2.ipynb`.
# 2. El notebook debe correr **de principio a fin** en el entorno del curso
#    (`uv sync`), leyendo los datos desde `datos/eod_stgo/`. Antes de entregar:
#    *Kernel → Restart & Run All*, y verifiquen que ninguna celda falle.
# 3. Cada ítem tiene tres partes: las instrucciones, una o más celdas de código, y
#    una celda de **Interpretación** que deben completar. Un resultado correcto sin
#    interpretación no otorga el puntaje completo.
#
# **Regla transversal de la tarea**
#
# Toda cifra que hable de la población debe estar **ponderada por el factor de
# expansión que corresponde a la unidad analizada**, usando como universo mínimo el
# **día laboral de temporada normal**: `Factor` para hogares,
# `Factor_LaboralNormal` para personas y `FactorLaboralNormal` para viajes (los dos
# últimos difieren solo en un guion bajo). Si deciden ampliar el universo (fin de
# semana, temporada estival), deben declararlo y usar los factores correspondientes.
# Una cifra muestral presentada como poblacional, o una cifra que no declara su
# universo, descuenta en el ítem.

# %% [markdown]
# ## 0. Configuración
#
# Esta celda deja listo lo que usarán en toda la tarea: las tres tablas
# principales, la edad y el universo de día laboral. Ojo: pandas no trae cuantiles
# ponderados; donde los necesiten, tendrán que ingeniárselas. **Complete su comuna y ejecútela antes que todo
# lo demás.** Los nombres de comuna vienen en mayúsculas y sin tildes (por
# ejemplo `"ESTACION CENTRAL"`).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RUTA = "datos/eod_stgo/"

MI_COMUNA = "COMPLETE_AQUI"        # en mayusculas, como en Hogares.csv
COMUNA_CONTRASTE = "COMPLETE_AQUI"

hogares = pd.read_csv(RUTA + "Hogares.csv", sep=";", decimal=",", low_memory=False)
personas = pd.read_csv(RUTA + "personas.csv", sep=";", decimal=",", low_memory=False)
viajes = pd.read_csv(RUTA + "viajes.csv", sep=";", decimal=",", low_memory=False)

# La encuesta registra el anio de nacimiento; la edad se calcula al 2013.
personas["Edad"] = 2013 - personas["AnoNac"]

# Universo minimo de la tarea: dia laboral de temporada normal.
# El factor viene vacio (NaN) para quienes no pertenecen a ese universo
# (encuestados de fin de semana y de temporada estival), asi que basta filtrar.
personas_lab = personas.dropna(subset=["Factor_LaboralNormal"])
viajes_lab = viajes.dropna(subset=["FactorLaboralNormal"])


print(f"hogares: {len(hogares):,} | personas: {len(personas):,} | viajes: {len(viajes):,}")
print(f"universo laboral: {len(personas_lab):,} personas, {len(viajes_lab):,} viajes")
# Out:
# hogares: 18,264 | personas: 60,054 | viajes: 113,591
# universo laboral: 37,326 personas, 78,820 viajes

# %% [markdown]
# ## Parte 1. Retrato numérico (25 puntos)

# %% [markdown]
# ### 1. La muestra y a quién representa (5 pts)
#
# **Instrucciones**
#
# - Reporten cuatro cifras para su comuna: hogares **encuestados**, personas
#   **encuestadas**, y hogares y personas **representados** según los factores de
#   expansión.
# - En la interpretación: expliquen en una frase por qué "encuestados" y
#   "representados" responden preguntas distintas.

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 2. Composición (6 pts)
#
# **Instrucciones**
#
# - Todo sobre `personas_lab` (universo laboral) y ponderado por
#   `Factor_LaboralNormal`.
# - Sexo: proporción ponderada de cada categoría, para su comuna y para el Gran
#   Santiago.
# - Edad: mediana y percentiles 25 y 75 **ponderados**, para su comuna y para el
#   Gran Santiago.
# - Presenten la comparación en una tabla (filas: indicador; columnas: comuna y
#   Gran Santiago).
# - En la interpretación: ¿en qué se parece y en qué difiere la composición de su
#   comuna respecto de la ciudad?

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 3. Ingresos (7 pts)
#
# **Instrucciones**
#
# - Con `IngresoHogar` de los hogares de su comuna, ponderado por `Factor`, y lo
#   mismo para la ciudad completa como referencia.
# - Reporten tres medidas ponderadas: la **media**, la **mediana** y la
#   **media truncada al 10%**: excluyan el 10% más
#   bajo y el 10% más alto (percentiles ponderados 10 y 90), y recalculen la media
#   ponderada con los que quedan.
# - En la interpretación: decidan cuál de las tres reportarían como "el ingreso de
#   la comuna" y justifíquenla a partir de la forma de la distribución de su
#   comuna (pueden apoyarse en un histograma ponderado), no como regla de memoria.

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 4. Una tabla que no vimos en clase: el parque vehicular (7 pts)
#
# **Instrucciones**
#
# - `Vehiculo.csv` tiene una fila por vehículo de cada hogar. Ojo: está
#   codificado en latin-1 (léanlo con `encoding="latin-1"`).
# - Una fila de esta tabla es un vehículo, no un hogar: **decidan y justifiquen
#   qué factor de expansión le corresponde** (esa justificación es parte del
#   puntaje).
# - Caractericen el parque vehicular de su comuna contra el de la ciudad, por
#   ejemplo con la antigüedad de los vehículos (mediana ponderada) y la proporción
#   ponderada con sello verde (`SelloVerde` viene codificado; su catálogo está en
#   `tablas_parametros/`).
# - Documenten las llaves usadas y verifiquen el merge (filas antes y después,
#   `NaN` nuevos).
# - En la interpretación: ¿qué dice el parque vehicular de su comuna comparado con
#   el de la ciudad?

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ## Parte 2. Retrato gráfico y asociaciones (30 puntos)
#
# En todos los gráficos de esta parte: título y ejes rotulados con unidades.
#
# Cuando un ítem habla de **los viajes de una comuna**, se refiere a los viajes con
# **origen** en ella (`ComunaOrigen`); pueden además presentar la mirada por destino
# si les aporta. `ComunaOrigen` viene codificada: se traduce con
# `tablas_parametros/Comuna.csv` (separado por comas y en latin-1).

# %% [markdown]
# ### 5. Distribución de ingresos (8 pts)
#
# **Instrucciones**
#
# - Un solo gráfico que permita comparar la **distribución completa** del ingreso
#   de los hogares de su comuna contra la del Gran Santiago (no basta comparar dos
#   promedios).
# - Debe estar ponderado por `Factor`. Ojo: la comuna y la ciudad tienen tamaños
#   muy distintos, así que las distribuciones deben quedar en una escala
#   comparable.
# - En la interpretación: justifiquen el tipo de gráfico elegido, digan qué
#   alternativa descartaron y por qué, y lean la comparación (¿dónde se concentra
#   su comuna respecto de la ciudad?).

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 6. La comuna de contraste (8 pts)
#
# **Instrucciones**
#
# - Elijan una comuna con un perfil de movilidad distinto al de la suya y
#   **justifiquen la elección con datos** (una cifra basta: reparto modal,
#   ingreso, tasa de viajes; no "porque la conocemos").
# - Calculen el reparto modal ponderado de las tres unidades: su comuna, la de
#   contraste y el Gran Santiago. El modo está en `ViajesDifusion.csv` (llave
#   `Viaje`) y su catálogo en `tablas_parametros/ModoDifusion.csv`; un viaje pertenece
#   a la comuna de su origen; el peso es `FactorLaboralNormal`.
# - Muestren las tres unidades en **una sola figura** (por ejemplo, barras
#   agrupadas o apiladas normalizadas). Si hay modos con muy pocos viajes,
#   agrúpenlos en "Otros".
# - En la interpretación: la lectura del contraste.

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 7. Ingreso y transporte público (8 pts)
#
# **Instrucciones**
#
# - Para **todas** las comunas del Gran Santiago calculen dos series: el ingreso
#   medio ponderado de los hogares (`IngresoHogar` con `Factor`) y la proporción
#   ponderada de viajes en transporte público (definan qué modos de
#   `ModoDifusion` cuentan como transporte público y declárenlo; el peso es
#   `FactorLaboralNormal`).
# - Grafiquen una contra la otra (cada punto, una comuna), destacando su comuna y
#   la de contraste.
# - Calculen las correlaciones de Pearson y de Spearman entre ambas series.
# - En la interpretación: ¿qué indica la diferencia entre ambos coeficientes?
#   ¿Qué comunas se apartan del patrón general, y dónde queda la suya?

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 8. Un hallazgo propio (6 pts)
#
# **Instrucciones**
#
# - Un gráfico adicional, a elección, que muestre algo del retrato que los ítems
#   anteriores no capturan. Se evalúa que el hallazgo **no sea trivial** (que no
#   repita lo ya visto ni algo obvio).
# - Ponderado como todo lo demás.
# - En la interpretación: la lectura del hallazgo en dos o tres líneas.

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ## Parte 3. Decisiones sobre los datos (25 puntos)

# %% [markdown]
# ### 9. Los que faltan (8 pts)
#
# **Instrucciones**
#
# - Identifiquen los datos faltantes que afectan su retrato: al menos
#   `IngresoHogar`, los factores de expansión, `TiempoViaje` y las coordenadas.
# - ¿Siguen algún patrón (por ejemplo, se concentran en algún grupo o comuna), o
#   pueden tratarse como ausencias sin estructura? Muestren la evidencia.
# - Recuerden lo visto en clase: un `NaN` en los factores no es un error, significa
#   "no pertenece a este universo".
# - Declaren qué decidieron hacer con los faltantes y **recalculen una de sus
#   cifras del retrato con la decisión contraria** para mostrar cuánto cambia.

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 10. Los extremos (8 pts)
#
# **Instrucciones**
#
# - Busquen valores extremos o sospechosos en las duraciones (`TiempoViaje`) y
#   distancias de los viajes con origen en su comuna (la distancia está en
#   `DistanciaViaje.csv`, llave `Viaje`, en metros).
# - Cuantifíquenlos con algún criterio explícito: la regla de Tukey del boxplot,
#   el criterio de desviaciones estándar respecto de la media (por ejemplo, tres
#   sigmas), u otro que conozcan y justifiquen.
# - Investíguenlos: ¿error de registro o viaje real posible? Declaren la decisión
#   (mantener, corregir o excluir) y muestren su **efecto sobre las medidas que
#   reportaron** (por ejemplo, la media y la mediana con y sin ellos).

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 11. Una transformación (9 pts)
#
# **Instrucciones**
#
# - Apliquen una transformación justificada a una variable de su retrato (por
#   ejemplo, logaritmo al ingreso o a la duración; si hay ceros, decidan y
#   declaren cómo los tratan antes del logaritmo).
# - Muestren el efecto con un gráfico del antes y el después (dos histogramas
#   ponderados lado a lado sirven).
# - En la interpretación: cómo cambia la forma de la distribución y qué medidas se
#   vuelven más o menos informativas después de transformar.

# %%
# Su código (agregue las celdas que necesite)

# %% [markdown]
# **Interpretación:** *(reemplace este texto por su respuesta)*

# %% [markdown]
# ## Parte 4. Síntesis (20 puntos)

# %% [markdown]
# ### 12. El retrato (8 pts)
#
# **Instrucciones**
#
# - Escriban aquí "El retrato de [su comuna]" en **máximo 10 líneas**, integrando
#   los hallazgos numéricos y gráficos de toda la tarea.
# - Debe poder leerse sola, sin el resto del notebook: con cifras concretas, no
#   con referencias a "el gráfico anterior".
#
# *(reemplace este texto por su retrato)*

# %% [markdown]
# ### 13. ¿De quién hablan sus números? (6 pts)
#
# **Instrucciones**
#
# - ¿Sus cifras hablan de la muestra, de su comuna, de la ciudad? ¿De qué días y
#   temporada, dado el universo que declararon?
# - ¿Qué personas o viajes podrían estar quedando fuera del retrato? Piensen en
#   quién responde una encuesta presencial de 2012 y quién no.
#
# *(reemplace este texto por su respuesta)*

# %% [markdown]
# ### 14. Una hipótesis para más adelante (6 pts)
#
# **Instrucciones**
#
# - Formulen una hipótesis **verificable** que su exploración sugiere pero no
#   demuestra (por ejemplo, sobre la relación entre dos variables de su comuna).
# - Se evalúa que sea precisa (variables medibles, dirección del efecto),
#   comprobable y motivada por sus datos. En la unidad 5 veremos cómo ponerla a
#   prueba.
#
# *(reemplace este texto por su hipótesis y su motivación en 2 a 4 líneas)*

# %% [markdown]
# ## Declaración de uso de IA generativa
#
# *(reemplace: qué herramienta usaron y para qué; una línea basta. Recuerden que
# deben poder explicar cualquier línea de su código si se les pregunta en clase.)*
#
# ## Antes de entregar
#
# - [ ] `Kernel → Restart & Run All` corre sin errores de principio a fin.
# - [ ] `MI_COMUNA` y `COMUNA_CONTRASTE` están definidas.
# - [ ] Toda cifra poblacional está ponderada y su universo está declarado.
# - [ ] Todos los gráficos tienen título y ejes rotulados con unidades.
# - [ ] Todas las celdas de "Interpretación" están completas.
# - [ ] El archivo se llama `tarea1_apellido1_apellido2.ipynb`.
# - [ ] La declaración de uso de IA está completa.
